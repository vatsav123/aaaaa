# %%
import pandas as pd
import numpy as np

# %%
df_train=pd.read_csv("house_pred.csv")
df_test=pd.read_csv("test.csv")

# %%
df_final=pd.DataFrame()

# %%
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df_train=df_train.drop(['Id','Alley','FireplaceQu','PoolQC','Fence', 'MiscFeature'],axis=1)
df_test=df_test.drop(['Id','Alley','FireplaceQu','PoolQC','Fence', 'MiscFeature'],axis=1)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   Utilities      1460 non-null   object
#  8   LotConfig      1460 non-null   object
#  9   LandSlope      1460 non-null   object
#  10  Neighborhood   1460 non-null   object
#  11  Condition1     1460 non-null   object
#  12  Condition2     1460 non-null   object
#  13  BldgType       1460 non-null   object
#  14  HouseStyle     1460 non-null   object
#  15  OverallQual    1460 non-null   int64
#  16  OverallCond    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lab=LabelEncoder()
for i in df_train.columns:
    if df_train[i].dtype=='object':
        df_train[i]=lab.fit_transform(df_train[i])

# %%
from sklearn.preprocessing import LabelEncoder
lab=LabelEncoder()
for i in df_test.columns:
    if df_test[i].dtype=='object':
        df_test[i]=lab.fit_transform(df_test[i])

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   int32
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   int32
#  5   LotShape       1460 non-null   int32
#  6   LandContour    1460 non-null   int32
#  7   Utilities      1460 non-null   int32
#  8   LotConfig      1460 non-null   int32
#  9   LandSlope      1460 non-null   int32
#  10  Neighborhood   1460 non-null   int32
#  11  Condition1     1460 non-null   int32
#  12  Condition2     1460 non-null   int32
#  13  BldgType       1460 non-null   int32
#  14  HouseStyle     1460 non-null   int32
#  15  OverallQual    1460 non-null   int64
#  16  OverallCond    1460 non-null   int64
#  17  YearBuilt      1460 non-null   int64
# ...

# %%
list=['MasVnrArea','GarageYrBlt','LotFrontage']

df_train['MasVnrArea'].fillna(df_train['MasVnrArea'].mean(),inplace=True)
df_train['GarageYrBlt'].fillna(df_train['GarageYrBlt'].mean(),inplace=True)
df_train['LotFrontage'].fillna(df_train['LotFrontage'].mean(),inplace=True)

df_test['MasVnrArea'].fillna(df_test['MasVnrArea'].mean(),inplace=True)
df_test['GarageYrBlt'].fillna(df_test['GarageYrBlt'].mean(),inplace=True)
df_test['LotFrontage'].fillna(df_test['LotFrontage'].mean(),inplace=True)

# %%
#outliers
Q1 = df_train.quantile(0.10)
Q3 = df_train.quantile(0.90)
# Calculate the interquartile range (IQR) for each column
IQR = Q3 - Q1
# Define the outlier boundaries for each column
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = 0
for i in df_train.columns:
    outliers_i = (df_train[i] < lower_bound[i]) | (df_train[i] > upper_bound[i])
    outliers |= outliers_i
    
df_no_outliers = df_train[~outliers]
print(outliers.sum())
# Out:
# 1033

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   int32
#  2   LotFrontage    1460 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   int32
#  5   LotShape       1460 non-null   int32
#  6   LandContour    1460 non-null   int32
#  7   Utilities      1460 non-null   int32
#  8   LotConfig      1460 non-null   int32
#  9   LandSlope      1460 non-null   int32
#  10  Neighborhood   1460 non-null   int32
#  11  Condition1     1460 non-null   int32
#  12  Condition2     1460 non-null   int32
#  13  BldgType       1460 non-null   int32
#  14  HouseStyle     1460 non-null   int32
#  15  OverallQual    1460 non-null   int64
#  16  OverallCond    1460 non-null   int64
#  17  YearBuilt      1460 non-null   int64
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def calculate_vif(df_train):
    vif_data = pd.DataFrame()
    vif_data["Feature"] = df_train.columns
    vif_data["VIF"] = [variance_inflation_factor(df_train.values, i) for i in range(len(df_train.columns))]
    return vif_data

vif_df = calculate_vif(df_train)
print("VIF for each feature:")
print(vif_df)
high_vif_columns = vif_df[vif_df['VIF'] > 4]['Feature'].tolist()
df = df_train.drop(columns=high_vif_columns)

print("Columns removed due to high VIF:", high_vif_columns)
# Out:
# C:\Users\sriva\anaconda3\Lib\site-packages\statsmodels\stats\outliers_influence.py:198: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# VIF for each feature:
#           Feature           VIF
# 0      MSSubClass     15.094293
# 1        MSZoning     31.809649
# 2     LotFrontage     19.636910
# 3         LotArea      3.479531
# 4          Street    281.549631
# ..            ...           ...
# 70         MoSold      6.813776
# 71         YrSold  43859.154823
# 72       SaleType     28.236713
# 73  SaleCondition     15.410447
# 74      SalePrice     41.185320
#
# [75 rows x 2 columns]
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def calculate_vif(df_test):
    vif_data = pd.DataFrame()
    vif_data["Feature"] = df_test.columns
    vif_data["VIF"] = [variance_inflation_factor(df_test.values, i) for i in range(len(df_test.columns))]
    return vif_data
vif_df = calculate_vif(df_test)
print("VIF for each feature:")
print(vif_df)
high_vif_columns = vif_df[vif_df['VIF'] > 4]['Feature'].tolist()
df_t = df_test.drop(columns=high_vif_columns)
print("Columns removed due to high VIF:", high_vif_columns)
# Out:
# C:\Users\sriva\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.uncentered_tss
# C:\Users\sriva\anaconda3\Lib\site-packages\statsmodels\stats\outliers_influence.py:198: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# VIF for each feature:
#           Feature           VIF
# 0      MSSubClass     30.826786
# 1        MSZoning     45.725672
# 2     LotFrontage     28.424698
# 3         LotArea     14.446058
# 4          Street           NaN
# ..            ...           ...
# 69        MiscVal     13.857914
# 70         MoSold      7.450333
# 71         YrSold  53523.592520
# 72       SaleType     44.640692
# 73  SaleCondition     19.452571
#
# [74 rows x 2 columns]
# ...

# %%
x=df_train.drop('SalePrice',axis=1)
y=df_train['SalePrice']

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
pred=reg.predict(x)

# %%
from sklearn.metrics import r2_score, mean_squared_error
r2_score(y,pred)
# Out:
# 0.8499268456677029

# %%
rmse=np.sqrt(mean_squared_error(y,pred))
rmse
# Out:
# 30764.909502715833

# %%
#test data
test_pred=reg.predict(df_test)
df_final['SalePrice']=test_pred
